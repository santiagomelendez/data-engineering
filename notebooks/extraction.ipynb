# %%
import sys; sys.path.append('..')
symbol = 'BTCUSDT'

# %%
from fetch_data import *

d = fetch_klines(symbol, '1h', '24')
print('amount of klines: ', len(d))
d
# Out:
# amount of klines:  24
# [[1707282000000,
#   '42929.18000000',
#   '43051.10000000',
#   '42882.00000000',
#   '43029.12000000',
#   '625.33484000',
#   1707285599999,
#   '26875347.95007300',
#   33881,
#   '306.35453000',
#   '13166553.42696270',
#   '0'],
#  [1707285600000,
#   '43029.12000000',
#   '43030.61000000',
#   '42891.52000000',
#   '42961.92000000',
#   '565.82276000',
#   1707289199999,
#   '24298702.71583180',
#   26364,
#   '228.82819000',
#   '9826805.33129350',
#   '0'],
#  [1707289200000,
#   '42961.92000000',
#   '43006.00000000',
#   '42900.00000000',
#   '42918.03000000',
#   '552.74195000',
#   1707292799999,
#   '23739554.12663800',
#   26497,
#   '231.85978000',
#   '9958541.55237510',
#   '0'],
#  [1707292800000,
#   '42918.02000000',
#   '42969.08000000',
#   '42872.37000000',
#   '42942.83000000',
#   '496.68460000',
#   1707296399999,
#   '21323225.36170190',
#   26936,
#   '218.60364000',
#   '9385032.57786930',
#   '0'],
#  [1707296400000,
# ...

# %%
import pandas as pd

data_columns = ['open_time', 'open_price', 'high_price', 
                'low_price', 'close_price', 'volume', 'close_time', 'quote_asset_volume', 
                'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'unused_field']

df = pd.DataFrame(d, columns=data_columns)

# %%
df.tail()
# Out:
#         open_time      open_price      high_price       low_price  \
# 19  1707346800000  44160.68000000  44363.80000000  44152.68000000
# 20  1707350400000  44349.60000000  44698.46000000  44331.10000000
# 21  1707354000000  44676.02000000  44695.47000000  44476.92000000
# 22  1707357600000  44654.73000000  44780.00000000  44536.01000000
# 23  1707361200000  44648.33000000  44727.42000000  44588.48000000
#
#        close_price         volume     close_time  quote_asset_volume  \
# 19  44349.60000000  1567.38592000  1707350399999   69358520.41373340
# 20  44676.01000000  3531.43254000  1707353999999  157237652.49816810
# 21  44654.73000000  1683.51254000  1707357599999   75058710.05528700
# 22  44648.32000000  2033.36119000  1707361199999   90751234.83578200
# 23  44611.29000000  1058.65278000  1707364799999   47282547.33017400
#
#     number_of_trades taker_buy_base_asset_volume taker_buy_quote_asset_volume  \
# ...

# %%
from utils.pandas_helpers import format_dataframe
df['symbol'] = 'btcusdt'
df_f = format_dataframe(df, time_unit='ms')

# %%
df.select_dtypes(include='float64').columns.to_list()
# Out:
# []

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   open_time                     24 non-null     datetime64[ns]
#  1   open_price                    24 non-null     object
#  2   high_price                    24 non-null     object
#  3   low_price                     24 non-null     object
#  4   close_price                   24 non-null     object
#  5   volume                        24 non-null     object
#  6   close_time                    24 non-null     datetime64[ns]
#  7   quote_asset_volume            24 non-null     object
#  8   number_of_trades              24 non-null     int64
#  9   taker_buy_base_asset_volume   24 non-null     object
#  10  taker_buy_quote_asset_volume  24 non-null     object
#  11  unused_field                  24 non-null     object
# ...

# %%
threshold = 49000
r = df_f.loc[(df_f['low_price'].astype(float) <= threshold) &  (threshold <= df_f['high_price'].astype(float))]

# %%
r.empty
# Out:
# True
